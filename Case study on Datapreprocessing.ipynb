# %%
import pandas as pd
import seaborn as sns
df=pd.read_csv("C:\\Users\\steph\\Downloads\\House_Pricing.csv")
df
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
df.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# ### Duplicate Removal

# %%
duplicated_rows= df.duplicated()

# %%
duplicated_rows.sum()
# Out:
# 0

# %%
dup_cols=df.columns.duplicated()

# %%
dup_cols.sum()
# Out:
# 0

# %% [markdown]
# ### Handling Missing Values

# %%
import matplotlib.pyplot as plt
sns.heatmap(df.isna())
plt.show()

# %%
# Checking missing values
df.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# ...

# %%
df1=df.drop(columns=["No of Times Visited"])
df1
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
df1.shape
# Out:
# (21613, 20)

# %%
# Handling Missing Values
num_df=df1.select_dtypes(include="number")
cat_df=df1.select_dtypes(include="object_")

# %%
print("Numerical columns are")
num_cols =num_df.columns.tolist()
print(num_cols)

cat_cols =cat_df.columns.tolist()
print("Categorical columns are")
print(cat_cols)
# Out:
# Numerical columns are
# ['ID', 'Sale Price', 'No of Bedrooms', 'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)', 'No of Floors', 'Overall Grade', 'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude', 'Longitude', 'Living Area after Renovation (in Sqft)', 'Lot Area after Renovation (in Sqft)']
# Categorical columns are
# ['Date House was Sold', 'Waterfront View', 'Condition of the House']

# %%
num_df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
for col in num_cols:
    num_df[col]=num_df[col].fillna(num_df[col].median())

# %%
num_df.isna().sum()
# Out:
# ID                                           0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
cat_df.isna().sum()
# Out:
# Date House was Sold       0
# Waterfront View           0
# Condition of the House    0
# dtype: int64

# %%
df2 = pd.concat([num_df,cat_df], axis=1)

# %%
df2.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0               1180.0              5650.0           1.0              7
# 1               2570.0              7242.0           2.0              7
# 2                770.0             10000.0           1.0              6
# 3               1960.0              5000.0           1.0              7
# 4               1680.0              8080.0           1.0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# ...

# %% [markdown]
# ### Scaling Numerical Variables

# %%
y=df2['Sale Price'] 
X=df2.drop('Sale Price',axis=1)

# %%
X.describe()
# Out:
#                  ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# count  2.161300e+04    21613.000000     21613.000000         21613.000000
# mean   4.580302e+09        3.370842         2.114757          2079.861010
# std    2.876566e+09        0.930062         0.770069           918.302876
# min    1.000102e+06        0.000000         0.000000           290.000000
# 25%    2.123049e+09        3.000000         1.750000          1430.000000
# 50%    3.904930e+09        3.000000         2.250000          1910.000000
# 75%    7.308900e+09        4.000000         2.500000          2550.000000
# max    9.900000e+09       33.000000         8.000000         13540.000000
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count        2.161300e+04  21613.000000   21613.000000
# mean         1.510464e+04      1.494309       7.623467
# std          4.141992e+04      0.539989       1.105439
# min          5.200000e+02      1.000000       1.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
print("Numerical columns(excluding the target variable SalePrice) are:")
num_cols1 =X.columns.tolist()
print(num_cols1)
# Out:
# Numerical columns(excluding the target variable SalePrice) are:
# ['ID', 'No of Bedrooms', 'No of Bathrooms', 'Flat Area (in Sqft)', 'Lot Area (in Sqft)', 'No of Floors', 'Overall Grade', 'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year', 'Zipcode', 'Latitude', 'Longitude', 'Living Area after Renovation (in Sqft)', 'Lot Area after Renovation (in Sqft)', 'Date House was Sold', 'Waterfront View', 'Condition of the House']

# %%
min_max_scalar= MinMaxScaler(feature_range=(0,1))
X['Flat_Area_min_max_scaled'] = min_max_scalar.fit_transform(X[['Flat Area (in Sqft)']])
X.head()
# Out:
#            ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0  7129300520               3             1.00               1180.0
# 1  6414100192               3             2.25               2570.0
# 2  5631500400               2             1.00                770.0
# 3  2487200875               4             3.00               1960.0
# 4  1954400510               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0              5650.0           1.0              7
# 1              7242.0           2.0              7
# 2             10000.0           1.0              6
# 3              5000.0           1.0              7
# 4              8080.0           1.0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# 1                                     2170.0                      400
# ...

# %%
std_scalar= StandardScaler()
X['Lot_Area_std_scaled'] = std_scalar.fit_transform(X[['Lot Area (in Sqft)']])
X.head()
# Out:
#            ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0  7129300520               3             1.00               1180.0
# 1  6414100192               3             2.25               2570.0
# 2  5631500400               2             1.00                770.0
# 3  2487200875               4             3.00               1960.0
# 4  1954400510               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0              5650.0           1.0              7
# 1              7242.0           2.0              7
# 2             10000.0           1.0              6
# 3              5000.0           1.0              7
# 4              8080.0           1.0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# 1                                     2170.0                      400
# ...

# %% [markdown]
# ### Encoding Categorical Variable

# %%
cat_cols =cat_df.columns.tolist()
print("Categorical columns are")
print(cat_cols)
# Out:
# Categorical columns are
# ['Date House was Sold', 'Waterfront View', 'Condition of the House']

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
# One Hot encoding
Waterfront_View_onehot = pd.get_dummies(df2,columns=['Waterfront View'],dtype=int) 
Waterfront_View_onehot.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0               1180.0              5650.0           1.0              7
# 1               2570.0              7242.0           2.0              7
# 2                770.0             10000.0           1.0              6
# 3               1960.0              5000.0           1.0              7
# 4               1680.0              8080.0           1.0              8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  ...  \
# 0                                     1180.0                        0  ...
# ...

# %%
# Label Encoding
label_enc=LabelEncoder()
df2['condition_encoded']=label_enc.fit_transform(df2['Condition of the House'])
df2
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                   1180.0              5650.0           1.0              7
# ...

# %% [markdown]
# ### Outlier Removal

# %%
plt.boxplot(num_df)
plt.show()

# %%
def remove_outliers(df2,column_name):
    q1=df2[column_name].quantile(0.25)
    q3=df2[column_name].quantile(0.75)
    iqr=q3-q1
    upper_bound=q3+1.5*iqr
    lower_bound=q1-1.5*iqr
    df2[column_name]=df2[column_name].clip(upper=upper_bound)
    df2[column_name]=df2[column_name].clip(lower=lower_bound)
    return df2[column_name]

# %%
for col in num_df:
    num_df[col]=remove_outliers(num_df, col)

# %%
plt.boxplot(num_df)
plt.show()

# %% [markdown]
# ### Train-Test Split

# %%
y=df2['Sale Price'] 
X=df2.drop('Sale Price',axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.2, random_state=2)

# %%
X_train
# Out:
#                ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 15166  3304700130               4             4.00               3860.0
# 13416  1115100119               4             2.00               1920.0
# 206    9526600140               3             2.50               2440.0
# 4286   9264921140               3             2.75               1910.0
# 18065  3826500730               4             2.50               2130.0
# ...           ...             ...              ...                  ...
# 1099   7227500830               2             1.00                720.0
# 18898   984220330               4             2.50               1820.0
# 11798  3629920990               4             3.25               3440.0
# 6637   3126049439               2             1.50                870.0
# 2575   3629970240               3             2.50               2820.0
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# ...

# %%
 y_train
# Out:
# 15166    1760000.0
# 13416     360000.0
# 206       677900.0
# 4286      300000.0
# 18065     220000.0
#            ...
# 1099      151000.0
# 18898     325000.0
# 11798     905000.0
# 6637      313000.0
# 2575      690000.0
# Name: Sale Price, Length: 17290, dtype: float64

# %%
X_test
# Out:
#                ID  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 6638   3491300052               4             2.25               2410.0
# 7366   8917100020               3             1.50               2170.0
# 3158   5100401429               2             1.00               1450.0
# 9117   1454600156               5             3.25               4500.0
# 3392   1917300025               2             1.00                860.0
# ...           ...             ...              ...                  ...
# 8494   7305300090               4             1.75               1530.0
# 5359   2310030500               3             1.75               1580.0
# 5242   1515910290               4             2.50               2650.0
# 13777  7625703065               2             1.00                820.0
# 1080   7888400560               4             2.75               1810.0
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# ...
